# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv('spam.csv')
X = data.drop('spam', axis=1)
y = data['spam']

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train the Logistic Regression model to classify emails as spam or not spam
model = LogisticRegression(max_iter=2000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)

# Visualize the confusion matrix using SeaBorn
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[-0.34243371 -0.16507191 -0.55676058 ... -0.13211609 -0.26259945
#   -0.46230847]
#  [ 1.98296202 -0.16507191  0.85172339 ... -0.13110745 -0.25746783
#   -0.41447594]
#  [-0.34243371 -0.16507191  1.24847944 ... -0.12202972 -0.23180971
#   -0.29736871]
#  ...
#  [-0.34243371 -0.16507191  2.6172878  ... -0.09854741 -0.2061516
#   -0.31056389]
#  [ 2.11397023 -0.16507191 -0.55676058 ... -0.09665621 -0.20101998
#   -0.32705787]
#  [-0.34243371  1.69476614 -0.55676058 ... -0.11017825 -0.19075673
#   -0.3748904 ]]
# Accuracy:  0.9196525515743756
# Precision:  0.9316939890710383
# Recall:  0.8743589743589744
# F1 Score:  0.9021164021164021
